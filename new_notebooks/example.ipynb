# %%
# 필수 기본 라이브러리
import numpy as np
import pandas as pd
import os
import copy

# 이미지 처리, 컴퓨터 비전
import cv2

# 시각화 툴
import matplotlib.pyplot as plt
import matplotlib.lines as mlines # 전체 서브플롯 관통하는 선 그리
from matplotlib import colormaps
import seaborn as sns

# 이미지 로드
from PIL import Image

# 딥러닝 라이브러리
import torch # PyTorch 기본 패키지. 텐서 생성, GPU 연산, 자동 미분등.
import torch.nn as nn # 신경망 레이어, 손실함수등.
import torch.nn.functional as F # 신경망에서 자주 쓰이는 함수들을 nn처럼 객체가 아닌 함수로 제공
from torch.nn import Sequential # 여러 레이어를 순서대로 쌓음
import torch.optim as optim # 옵티마이저 제공
import torchvision.models as models # 이미 학습된 CNN 모델 제공
import torchvision.transforms as transforms # 이미지 전처리 도구
from torch.utils.data import DataLoader, Dataset, TensorDataset # 사용자 정의 데이터셋 제작

# 사이킷런 툴
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, StratifiedKFold

# 머신러닝 툴
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# 시드 고정
torch.manual_seed(42)
np.random.seed(42)

# GPU 사용 가능 여부에 따라 device 설정
if torch.cuda.is_available():
    device = torch.device('cuda')
    print(torch.cuda.get_device_name(device))
    print('device connected')
else:
    device = torch.device('cpu')
    print('No GPU available, using CPU')

# 이후 device를 모델 등에 사용 가능
# model.to(device)
